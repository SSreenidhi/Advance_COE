# %%
import pandas as pd
msg=pd.read_csv("/content/SMSSpamCollection.txt",sep="\t",names=["label","message"])

# %%
msg
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
Sentences=msg['message'].apply(sent_tokenize)

# %%
print(Sentences[0])
# Out:
# ['Go until jurong point, crazy..', 'Available only in bugis n great world la e buffet... Cine there got amore wat...']

# %%
len(Sentences)
# Out:
# 5572

# %%
tokens=msg['message'].apply(word_tokenize)

# %%
print(tokens)
# Out:
# 0       [Go, until, jurong, point, ,, crazy, .., Avail...
# 1                [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2       [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3       [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4       [Nah, I, do, n't, think, he, goes, to, usf, ,,...
#                               ...
# 5567    [This, is, the, 2nd, time, we, have, tried, 2,...
# 5568      [Will, ü, b, going, to, esplanade, fr, home, ?]
# 5569    [Pity, ,, *, was, in, mood, for, that, ., So, ...
# 5570    [The, guy, did, some, bitching, but, I, acted,...
# 5571                  [Rofl, ., Its, true, to, its, name]
# Name: message, Length: 5572, dtype: object

# %%
len(tokens)
# Out:
# 5572

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def tokenize(msg):
    tokens = nltk.word_tokenize(msg.lower())
    return [word for word in tokens if word.isalpha()]

# %%
msg['tokenized'] = msg['message'].apply(tokenize)

# %%
stop_words = set(stopwords.words('english'))

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = text.split()
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(tokens)

# %%
msg['processed_msg'] = msg['message'].apply(preprocess_text)

# %%
msg.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                            tokenized  \
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, a, wkly, comp, to, win, fa, ...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, do, think, he, goes, to, usf, he, liv...
#
#                                        processed_msg
# 0  go jurong point crazy available bugis n great ...
# 1                            ok lar joking wif u oni
# 2  free entry wkly comp win fa cup final tkts st ...
# 3                u dun say early hor u c already say
# ...

# %%
 pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import pandas as pd
import nltk
from nltk import word_tokenize, pos_tag

def get_pos_tags(text):
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
    pos_tags_dict = {word: tag for word, tag in pos_tags}
    return pos_tags

# %%
msg['pos_tagss'] = msg['message'].apply(get_pos_tags)

# %%
msg.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                            tokenized  \
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, a, wkly, comp, to, win, fa, ...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, do, think, he, goes, to, usf, he, liv...
#
#                                        processed_msg  \
# 0  go jurong point crazy available bugis n great ...
# 1                            ok lar joking wif u oni
# 2  free entry wkly comp win fa cup final tkts st ...
# 3                u dun say early hor u c already say
# ...

# %%
msg.shape
# Out:
# (5572, 5)

# %%
all_tokens_list = msg['tokenized'].tolist()

word_count = sum(len(sublist) for sublist in all_tokens_list)
print(f"Total number of words in the 'tokenized' column: {word_count}")
# Out:
# Total number of words in the 'tokenized' column: 81900

# %%
corpus=[]
for i in range(0,len(msg)):
  review=re.sub('[^a-zA-Z]',' ',msg['message'][i])
  review=review.lower()
  review=review.split()
  review=[lemmatizer.lemmatize(word) for word in review if not word in stopwords.words('english')]
  review=' '.join(review)
  corpus.append(review)

# %%
corpus[0]
# Out:
# 'go jurong point crazy available bugis n great world la e buffet cine got amore wat'

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2500)
X=cv.fit_transform(corpus).toarray()

# %%
X.shape
# Out:
# (5572, 2500)

# %%
X[0].shape
# Out:
# (2500,)

# %%
corpus[1]
# Out:
# 'ok lar joking wif u oni'

# %% [markdown]
# # **with spacy library**

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/pip/__main__.py", line 22, in <module>
#     from pip._internal.cli.main import main as _main

# %%
import pandas as pd
msg2=pd.read_csv("/content/SMSSpamCollection.txt",sep="\t",names=["label","message"])

# %%
import spacy
import pandas as pd
nlp = spacy.load('en_core_web_sm')

# %%
for token in msg2['message']:
  doc=nlp(token)
  print(doc)
# Out:
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# Ok lar... Joking wif u oni...
# Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# U dun say so early hor... U c already then say...
# Nah I don't think he goes to usf, he lives around here though
# FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv
# Even my brother is not like to speak with me. They treat me like aids patent.
# As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
# WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.
# ...

# %%
for token in doc:
  print(token.text,token.pos_)
# Out:
# Sorry INTJ
# to PART
# trouble VERB
# u PRON
# again ADV
# . PUNCT
# Can AUX
# buy VERB
# 4d NOUN
# for ADP
# my PRON
# dad NOUN
# again ADV
# ? PUNCT
# 1405 NUM
# , PUNCT
# 1680 NUM
# , PUNCT
# 1843 NUM
# . PUNCT
# All PRON
# 2 NUM
# big ADJ
# 1 NUM
# small ADJ
# , PUNCT
# sat VERB
# n PROPN
# sun PROPN
# . PUNCT
# Thanx PROPN
# . PUNCT

# %%
for token in doc:
  print(token.lemma_)
# Out:
# sorry
# to
# trouble
# u
# again
# .
# can
# buy
# 4d
# for
# my
# dad
# again
# ?
# 1405
# ,
# 1680
# ,
# 1843
# .
# all
# 2
# big
# 1
# small
# ,
# sit
# n
# sun
# .
# Thanx
# .

# %%
for token in doc:
  print(token.is_punct)
# Out:
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# True
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# False
# True

# %%
for token in doc:
  print(token.is_alpha)
# Out:
# True
# True
# True
# True
# True
# False
# True
# True
# False
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# True
# False
# True
# True
# True
# False
# True
# False

# %%
for token in doc:
  print(token.is_stop)
# Out:
# False
# True
# False
# False
# True
# False
# True
# False
# False
# True
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for token in doc:
  print(token.like_email)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
doc.ents
# Out:
# (4d, 1405, 1680, 1843, 2, 1)

# %%
for ent in doc.ents:
    print(ent.text,ent.start_char,ent.end_char,ent.label_)
# Out:
# 4d 34 36 CARDINAL
# 1405 55 59 DATE
# 1680 61 65 DATE
# 1843 67 71 DATE
# 2 77 78 CARDINAL
# 1 83 84 CARDINAL

# %%
def tokenize_text(text):
    doc = nlp(text)
    return [token.text for token in doc if not token.is_space]

# %%
msg2['tokenized'] = msg['message'].apply(tokenize)

# %%
def spacy_preprocess(text):
    doc = nlp(text.lower())
    tokens = []

    for token in doc:
        if (
            token.is_alpha
            and not token.is_stop
            and not token.is_punct
            and not token.like_email
            and not token.like_num
            and not token.like_url
            and not token.ent_type_
        ):
            tokens.append(token.lemma_)

    return ' '.join(tokens)

# %%
msg2['processed'] = msg['message'].apply(spacy_preprocess)

# %%
msg2.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                            tokenized  \
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, a, wkly, comp, to, win, fa, ...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, do, think, he, goes, to, usf, he, liv...
#
#                                            processed
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry wkly comp win fa cup final tkts tex...
# 3                                u dun early hor u c
# ...
