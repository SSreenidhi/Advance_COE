# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset("diamonds")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df['cut'].unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df['color'].unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df['clarity'].unique()
# Out:
# ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']
# Categories (8, object): ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1']

# %%
df['cut']=df['cut'].map({'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5})
df['color']=df['color'].map({'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7})
df['clarity']=df['clarity'].map({'I1':1,'SI2':2,'SI1':3,'VS2':4,'VS1':5,'VVS2':6,'VVS1':7,'IF':8})

# %%
df.head()
# Out:
#    carat cut color clarity  depth  table  price     x     y     z
# 0   0.23   5     2       2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   4     2       3   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23   2     2       5   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29   4     6       4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31   2     7       2   63.3   58.0    335  4.34  4.35  2.75

# %%
from sklearn.preprocessing import MinMaxScaler

X = df.drop('cut', axis=1)
y = df['cut']

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (43152, 9)
# (10788, 9)
# (43152,)
# (10788,)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
y_pred.shape
# Out:
# (10788,)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7883759733036707
#               precision    recall  f1-score   support
#
#            1       0.91      0.90      0.91       335
#            2       0.80      0.72      0.75      1004
#            3       0.68      0.54      0.61      2382
#            4       0.78      0.81      0.79      2775
#            5       0.83      0.92      0.87      4292
#
#     accuracy                           0.79     10788
#    macro avg       0.80      0.78      0.79     10788
# weighted avg       0.78      0.79      0.78     10788

# %%
from sklearn.tree import DecisionTreeClassifier
model1 =DecisionTreeClassifier()
model1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1=model1.predict(X_test)

# %%
X_test.shape
# Out:
# (10788, 9)

# %%
y_pred1.shape
# Out:
# (10788,)

# %%
from sklearn.metrics import accuracy_score,classification_report
accuracy = accuracy_score(y_test, y_pred1)
print(f"Accuracy: {accuracy}")
print(classification_report(y_test, y_pred1))
# Out:
# Accuracy: 0.7136633296255098
#               precision    recall  f1-score   support
#
#            1       0.88      0.84      0.86       335
#            2       0.66      0.68      0.67      1004
#            3       0.53      0.55      0.54      2382
#            4       0.75      0.73      0.74      2775
#            5       0.80      0.80      0.80      4292
#
#     accuracy                           0.71     10788
#    macro avg       0.72      0.72      0.72     10788
# weighted avg       0.72      0.71      0.71     10788

# %%
preds=model.predict(X_test[:10])
preds
# Out:
# array([5, 5, 5, 5, 5, 1, 5, 5, 4, 5])
